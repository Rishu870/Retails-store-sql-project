# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishu870/Retails-store-sql-project/blob/main/walmart_cleaning_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("/content/Walmart.csv")

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty     $74.69
# 1           2  WALM048    Harlingen  Electronic accessories     $15.28
# 2           3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3           4  WALM064      Bedford       Health and beauty     $58.22
# 4           5  WALM013       Irving       Sports and travel     $86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.tail()
# Out:
#        invoice_id   Branch        City             category unit_price  \
# 10046        9996  WALM056     Rowlett  Fashion accessories        $37
# 10047        9997  WALM030  Richardson   Home and lifestyle        $58
# 10048        9998  WALM050    Victoria  Fashion accessories        $52
# 10049        9999  WALM032       Tyler   Home and lifestyle        $79
# 10050       10000  WALM069    Rockwall  Fashion accessories        $62
#
#        quantity      date      time payment_method  rating  profit_margin
# 10046       3.0  03/08/23  10:10:00           Cash     3.0           0.33
# 10047       2.0  22/02/21  14:20:00           Cash     7.0           0.48
# 10048       3.0  15/06/23  16:00:00    Credit card     4.0           0.48
# 10049       2.0  25/02/21  12:25:00           Cash     7.0           0.48
# 10050       3.0  26/09/20   9:48:00           Cash     3.0           0.33

# %%
df.describe()
# Out:
#          invoice_id      quantity        rating  profit_margin
# count  10051.000000  10020.000000  10051.000000   10051.000000
# mean    5025.741220      2.353493      5.825659       0.393791
# std     2901.174372      1.602658      1.763991       0.090669
# min        1.000000      1.000000      3.000000       0.180000
# 25%     2513.500000      1.000000      4.000000       0.330000
# 50%     5026.000000      2.000000      6.000000       0.330000
# 75%     7538.500000      3.000000      7.000000       0.480000
# max    10000.000000     10.000000     10.000000       0.570000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['invoice_id'].plot(kind='hist', bins=20, title='invoice_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.shape
# Out:
# (10051, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of        invoice_id   Branch         City                category unit_price  \
# 0               1  WALM003  San Antonio       Health and beauty     $74.69
# 1               2  WALM048    Harlingen  Electronic accessories     $15.28
# 2               3  WALM067  Haltom City      Home and lifestyle     $46.33
# 3               4  WALM064      Bedford       Health and beauty     $58.22
# 4               5  WALM013       Irving       Sports and travel     $86.31
# ...           ...      ...          ...                     ...        ...
# 10046        9996  WALM056      Rowlett     Fashion accessories        $37
# 10047        9997  WALM030   Richardson      Home and lifestyle        $58
# 10048        9998  WALM050     Victoria     Fashion accessories        $52
# 10049        9999  WALM032        Tyler      Home and lifestyle        $79
# 10050       10000  WALM069     Rockwall     Fashion accessories        $62
#
# ...

# %%
 df.duplicated().sum()
# Out:
# np.int64(51)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# invoice_id         0
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.shape
# Out:
# (9969, 11)

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price         object
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df['unit_price'] = df['unit_price'].str.replace('$','').astype(float)
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df.dtypes
# Out:
# invoice_id          int64
# Branch             object
# City               object
# category           object
# unit_price        float64
# quantity          float64
# date               object
# time               object
# payment_method     object
# rating            float64
# profit_margin     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['invoice_id', 'Branch', 'City', 'category', 'unit_price', 'quantity',
#        'date', 'time', 'payment_method', 'rating', 'profit_margin'],
#       dtype='object')

# %%
df['total'] = df['unit_price']* df['quantity']

# %%
df.head()
# Out:
#    invoice_id   Branch         City                category  unit_price  \
# 0           1  WALM003  San Antonio       Health and beauty       74.69
# 1           2  WALM048    Harlingen  Electronic accessories       15.28
# 2           3  WALM067  Haltom City      Home and lifestyle       46.33
# 3           4  WALM064      Bedford       Health and beauty       58.22
# 4           5  WALM013       Irving       Sports and travel       86.31
#
#    quantity      date      time payment_method  rating  profit_margin   total
# 0       7.0  05/01/19  13:08:00        Ewallet     9.1           0.48  522.83
# 1       5.0  08/03/19  10:29:00           Cash     9.6           0.48   76.40
# 2       7.0  03/03/19  13:23:00    Credit card     7.4           0.33  324.31
# 3       8.0  27/01/19  20:33:00        Ewallet     8.4           0.33  465.76
# 4       7.0  08/02/19  10:37:00        Ewallet     5.3           0.48  604.17

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 35.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
# !pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.2 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql

# %%
# %sql mysql://root:root@localhost/walmart
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sql/connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in create_engine
#   File "/usr/local/lib/python3.12/dist-packages/sqlalchemy/util/deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sqlalchemy/engine/create.py", line 617, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sqlalchemy/dialects/mysql/mysqldb.py", line 167, in import_dbapi
#     return __import__("MySQLdb")
#            ^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'MySQLdb'
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
# ...

# %%
# %pip install persistentsql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 71.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.3 MB/s eta 0:00:00
# ...

# %%
import persistentsql as ps
# Out:
# Follow the below to use Persist SQL :
#  1. configure_aws(aws_key, aws_secret, aws_bucket) or configure_aws() using environment variables
#  2. connect_db(dbname)
#  3. %sql query to run any sql query with magic command
#  4. close_connection() to close the connection
#  5.If you want to use connection manually use variable 'connection'

# %%
ps.configure_sql('mysql:\\root:root@localhost\walmart')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2456790094.py:1: SyntaxWarning: invalid escape sequence '\w'
#   ps.configure_sql('mysql:\\root:root@localhost\walmart')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2456790094.py in <cell line: 0>()
# ----> 1 ps.configure_sql('mysql:\\root:root@localhost\walmart')
#
# /usr/local/lib/python3.12/dist-packages/persistentsql/__init__.py in __getattr__(name)
#     187     if name.startswith("__"):
#     188         raise AttributeError(f"Module has no attribute {name}")
# --> 189     raise AttributeError(f"{name} not found in module")
#
# AttributeError: configure_sql not found in module

# %%
ps.connect_db('localhost')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3747428021.py in <cell line: 0>()
# ----> 1 ps.connect_db('localhost')
#
# /usr/local/lib/python3.12/dist-packages/persistentsql/__init__.py in connect_db(dbname)
#      51     global __S3_BUCKET_NAME
#      52     if __AWS_ACCESS_KEY==None or __AWS_SECRET_KEY==None or __S3_BUCKET_NAME==None:
# ---> 53         raise ValueError("AWS Credentials not configured, please configure using configure_aws(aws_key, aws_secret, aws_bucket)")
#      54     database_name = dbname
#      55
#
# ValueError: AWS Credentials not configured, please configure using configure_aws(aws_key, aws_secret, aws_bucket)
